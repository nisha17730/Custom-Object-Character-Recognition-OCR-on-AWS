# %% [markdown]
# # Run Inference on New Images and Preprocess Detected Regions

# %%
import cv2
import numpy as np
import os
import pytesseract
import pandas as pd

# %% [markdown]
# # Configuration and Path Setup

# %%
MODEL_CONFIG = r"C:\Users\hp\project 10\yolo_model\yolov3.cfg"
MODEL_WEIGHTS = r"C:\Users\hp\project 10\yolo_model\yolov3.weights"
CLASS_NAMES = r"C:\Users\hp\project 10\yolo_model\coco.names"
EAST_MODEL = r"C:\Users\hp\project 10\yolo_model\frozen_east_text_detection.pb"

INPUT_IMAGES_FOLDER = r"C:\Users\hp\project 10\raw_images"
OUTPUT_DETECTED_FOLDER = r"C:\Users\hp\project 10\detected_regions"
OUTPUT_PREPROCESSED_FOLDER = r"C:\Users\hp\project 10\preprocessed_images"
OUTPUT_CSV = r"C:\Users\hp\project 10\output.csv"

# Ensure output directories exist
os.makedirs(OUTPUT_DETECTED_FOLDER, exist_ok=True)
os.makedirs(OUTPUT_PREPROCESSED_FOLDER, exist_ok=True)

# Load EAST Text Detector model
net = cv2.dnn.readNet(EAST_MODEL)

# Load class names
with open(CLASS_NAMES, "r") as f:
    classes = f.read().strip().split("\n")

# Setup Tesseract OCR
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %% [markdown]
# # Function: Detect Text Regions Using EAST Model

# %%
def detect_text_regions(image_path):
    """
    Detect text regions in an image using the EAST model.
    :param image_path: Path to the input image.
    :return: List of detected text region image paths.
    """
    image = cv2.imread(image_path)
    orig = image.copy()
    (H, W) = image.shape[:2]

    # Resize image for EAST model (must be multiple of 32)
    newW, newH = (320, 320)
    rW, rH = W / float(newW), H / float(newH)
    image = cv2.resize(image, (newW, newH))
    blob = cv2.dnn.blobFromImage(image, 1.0, (newW, newH), (123.68, 116.78, 103.94), swapRB=True, crop=False)
    net.setInput(blob)
    (scores, geometry) = net.forward(["feature_fusion/Conv_7/Sigmoid", "feature_fusion/concat_3"])

    # Decode detected text regions
    boxes = []
    confidences = []
    for y in range(geometry.shape[2]):
        for x in range(geometry.shape[3]):
            if scores[0, 0, y, x] < 0.5:
                continue
            
            offsetX, offsetY = x * 4.0, y * 4.0
            angle = geometry[0, 4, y, x]
            cosA, sinA = np.cos(angle), np.sin(angle)
            h, w = geometry[0, 0, y, x], geometry[0, 1, y, x]
            endX, endY = int(offsetX + (cosA * w) + (sinA * h)), int(offsetY - (sinA * w) + (cosA * h))
            startX, startY = int(endX - w), int(endY - h)
            
            startX, startY, endX, endY = int(startX * rW), int(startY * rH), int(endX * rW), int(endY * rH)
            boxes.append((startX, startY, endX, endY))
            confidences.append(scores[0, 0, y, x])
    
    # Apply Non-Maximum Suppression (NMS)
    indices = cv2.dnn.NMSBoxes(boxes, confidences, 0.5, 0.4)
    detected_images = []

    if len(indices) > 0:
        for i in indices.flatten():
            x1, y1, x2, y2 = boxes[i]
            cropped_region = orig[y1:y2, x1:x2]
            output_path = os.path.join(OUTPUT_DETECTED_FOLDER, f"region_{i}.jpg")
            cv2.imwrite(output_path, cropped_region)
            detected_images.append(output_path)
    
    return detected_images

# %% [markdown]
# # Function: Extract Text Using Tesseract OCR

# %%
def extract_text(image_path):
    """
    Extract text from an image using Tesseract OCR.
    :param image_path: Path to the input image.
    :return: Extracted text.
    """
    image = cv2.imread(image_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    text = pytesseract.image_to_string(gray, config='--psm 6')
    return text.strip()

# %% [markdown]
# # Main OCR Pipeline Execution

# %%
ocr_results = []
for filename in os.listdir(INPUT_IMAGES_FOLDER):
    input_path = os.path.join(INPUT_IMAGES_FOLDER, filename)
    
    # Step 1: Detect text regions
    detected_regions = detect_text_regions(input_path)
    
    # Step 2: Extract text from detected text regions
    for detected_img in detected_regions:
        extracted_text = extract_text(detected_img)
        ocr_results.append((detected_img, extracted_text))

# Save OCR results to CSV
if ocr_results:
    df = pd.DataFrame(ocr_results, columns=["Image Path", "Extracted Text"])
    df.to_csv(OUTPUT_CSV, index=False)
    print("OCR Process Complete! Extracted text saved to CSV.")
else:
    print("No text detected in any image.")
# Out:
# OCR Process Complete! Extracted text saved to CSV.

# %% [markdown]
# # Extracting Text Using Tesseract

# %%
import cv2
import numpy as np
import os
import pytesseract
import csv

# Define paths
MODEL_CONFIG = r"C:\Users\hp\project 10\yolo_model\yolov3.cfg"
MODEL_WEIGHTS = r"C:\Users\hp\project 10\yolo_model\yolov3.weights"
CLASS_NAMES = r"C:\Users\hp\project 10\yolo_model\coco.names"
INPUT_IMAGES_FOLDER = r"C:\Users\hp\project 10\raw_images"
OUTPUT_DETECTED_FOLDER = r"C:\Users\hp\project 10\detected_regions"
OUTPUT_PREPROCESSED_FOLDER = r"C:\Users\hp\project 10\preprocessed_images"
OUTPUT_CSV = r"C:\Users\hp\project 10\output.csv"

# Ensure output folders exist
os.makedirs(OUTPUT_DETECTED_FOLDER, exist_ok=True)
os.makedirs(OUTPUT_PREPROCESSED_FOLDER, exist_ok=True)

# Load YOLO model
net = cv2.dnn.readNet(MODEL_WEIGHTS, MODEL_CONFIG)
with open(CLASS_NAMES, "r") as f:
    classes = f.read().strip().split("\n")
layer_names = net.getLayerNames()
out_layers = [layer_names[i - 1] for i in net.getUnconnectedOutLayers().flatten()]

def detect_text_regions(image_path):
    image = cv2.imread(image_path)
    height, width = image.shape[:2]
    
    # Prepare image for YOLO
    blob = cv2.dnn.blobFromImage(image, 1/255.0, (416, 416), swapRB=True, crop=False)
    net.setInput(blob)
    layer_outputs = net.forward(out_layers)
    
    boxes, confidences = [], []
    for output in layer_outputs:
        for detection in output:
            scores = detection[5:]
            class_id = np.argmax(scores)
            confidence = scores[class_id]
            if confidence > 0.5 and classes[class_id] == "text":
                box = detection[0:4] * np.array([width, height, width, height])
                (centerX, centerY, w, h) = box.astype("int")
                x, y = int(centerX - w / 2), int(centerY - h / 2)
                boxes.append([x, y, int(w), int(h)])
                confidences.append(float(confidence))
    
    # Apply Non-Maximum Suppression
    indices = cv2.dnn.NMSBoxes(boxes, confidences, 0.5, 0.4)
    detected_images = []
    if len(indices) > 0:
        for i in indices.flatten():
            x, y, w, h = boxes[i]
            cropped_region = image[y:y+h, x:x+w]
            output_path = os.path.join(OUTPUT_DETECTED_FOLDER, f"detected_{os.path.basename(image_path)}")
            cv2.imwrite(output_path, cropped_region)
            detected_images.append(output_path)
    return detected_images

# Run inference on new images
for filename in os.listdir(INPUT_IMAGES_FOLDER):
    input_path = os.path.join(INPUT_IMAGES_FOLDER, filename)
    detect_text_regions(input_path)

print("Inference complete! Detected regions saved.")

# --- PREPROCESS DETECTED REGIONS ---
def preprocess_image(image_path, output_path):
    image = cv2.imread(image_path)
    if image is None:
        print(f"Error: Could not read {image_path}")
        return
    
    # Resize the image (scale 3x)
    image_resized = cv2.resize(image, None, fx=3, fy=3, interpolation=cv2.INTER_LINEAR)
    
    # Convert to grayscale
    gray = cv2.cvtColor(image_resized, cv2.COLOR_BGR2GRAY)
    
    # Apply Gaussian blur
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)
    
    # Apply thresholding (Otsu's method)
    _, thresh = cv2.threshold(blurred, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    
    # Invert colors for better OCR accuracy
    processed = cv2.bitwise_not(thresh)
    
    # Save the preprocessed image
    cv2.imwrite(output_path, processed)
    print(f"Processed image saved: {output_path}")

# Process all detected region images
for filename in os.listdir(OUTPUT_DETECTED_FOLDER):
    input_path = os.path.join(OUTPUT_DETECTED_FOLDER, filename)
    output_path = os.path.join(OUTPUT_PREPROCESSED_FOLDER, filename)
    preprocess_image(input_path, output_path)

print("Preprocessing complete!")

# --- EXTRACT TEXT USING TESSERACT ---
def extract_text(image_path):
    image = cv2.imread(image_path)
    if image is None:
        return ""
    text = pytesseract.image_to_string(image, config='--psm 6')
    return text.strip()

# Open CSV file to write extracted text
with open(OUTPUT_CSV, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(["Filename", "Extracted Text"])
    
    for filename in os.listdir(OUTPUT_PREPROCESSED_FOLDER):
        input_path = os.path.join(OUTPUT_PREPROCESSED_FOLDER, filename)
        extracted_text = extract_text(input_path)
        writer.writerow([filename, extracted_text])
        print(f"Text extracted from {filename} and saved.")

print("Text extraction complete! CSV file saved.")
# Out:
# Inference complete! Detected regions saved.
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_0.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_1.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_10.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_100.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_101.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_102.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_103.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_104.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_105.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_106.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_107.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_108.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_109.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_11.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_110.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_111.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_112.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_113.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_114.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_115.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_116.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_117.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_118.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_119.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_12.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_120.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_121.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_122.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_123.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_124.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_125.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_126.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_127.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_128.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_129.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_13.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_130.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_131.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_132.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_133.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_134.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_135.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_136.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_137.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_138.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_139.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_14.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_140.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_141.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_142.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_143.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_144.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_145.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_146.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_147.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_149.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_15.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_150.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_151.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_152.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_153.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_154.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_155.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_156.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_158.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_159.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_16.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_160.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_162.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_163.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_164.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_165.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_166.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_167.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_168.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_169.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_17.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_170.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_171.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_172.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_173.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_174.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_175.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_176.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_177.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_178.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_179.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_18.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_180.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_181.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_182.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_183.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_184.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_186.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_187.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_188.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_189.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_19.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_190.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_191.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_192.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_193.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_195.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_196.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_197.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_199.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_2.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_20.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_200.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_201.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_203.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_204.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_205.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_206.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_207.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_21.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_210.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_211.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_212.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_213.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_215.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_216.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_217.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_218.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_22.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_220.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_221.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_224.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_225.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_226.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_227.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_229.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_23.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_232.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_233.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_234.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_237.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_238.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_239.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_24.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_245.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_247.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_248.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_25.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_252.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_253.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_255.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_257.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_258.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_259.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_26.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_260.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_261.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_262.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_263.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_264.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_267.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_268.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_269.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_27.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_272.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_273.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_277.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_279.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_28.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_280.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_288.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_29.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_293.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_3.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_30.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_31.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_318.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_32.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_321.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_33.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_330.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_34.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_35.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_351.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_359.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_36.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_366.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_37.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_373.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_38.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_39.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_4.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_40.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_41.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_42.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_43.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_44.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_45.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_46.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_47.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_48.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_49.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_5.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_50.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_51.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_52.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_53.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_54.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_55.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_56.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_57.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_58.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_59.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_6.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_60.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_61.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_62.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_63.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_64.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_65.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_66.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_67.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_68.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_69.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_7.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_70.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_71.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_72.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_73.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_74.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_75.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_76.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_77.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_78.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_79.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_8.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_80.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_81.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_82.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_83.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_84.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_85.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_86.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_87.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_88.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_89.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_9.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_90.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_91.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_92.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_93.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_94.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_95.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_96.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_97.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_98.jpg
# Processed image saved: C:\Users\hp\project 10\preprocessed_images\region_99.jpg
# Preprocessing complete!
# Text extracted from region_0.jpg and saved.
# Text extracted from region_1.jpg and saved.
# Text extracted from region_10.jpg and saved.
# Text extracted from region_100.jpg and saved.
# Text extracted from region_101.jpg and saved.
# Text extracted from region_102.jpg and saved.
# Text extracted from region_103.jpg and saved.
# Text extracted from region_104.jpg and saved.
# Text extracted from region_105.jpg and saved.
# Text extracted from region_106.jpg and saved.
# Text extracted from region_107.jpg and saved.
# Text extracted from region_108.jpg and saved.
# Text extracted from region_109.jpg and saved.
# Text extracted from region_11.jpg and saved.
# Text extracted from region_110.jpg and saved.
# Text extracted from region_111.jpg and saved.
# Text extracted from region_112.jpg and saved.
# Text extracted from region_113.jpg and saved.
# Text extracted from region_114.jpg and saved.
# Text extracted from region_115.jpg and saved.
# Text extracted from region_116.jpg and saved.
# Text extracted from region_117.jpg and saved.
# Text extracted from region_118.jpg and saved.
# Text extracted from region_119.jpg and saved.
# Text extracted from region_12.jpg and saved.
# Text extracted from region_120.jpg and saved.
# Text extracted from region_121.jpg and saved.
# Text extracted from region_122.jpg and saved.
# Text extracted from region_123.jpg and saved.
# Text extracted from region_124.jpg and saved.
# Text extracted from region_125.jpg and saved.
# Text extracted from region_126.jpg and saved.
# Text extracted from region_127.jpg and saved.
# Text extracted from region_128.jpg and saved.
# Text extracted from region_129.jpg and saved.
# Text extracted from region_13.jpg and saved.
# Text extracted from region_130.jpg and saved.
# Text extracted from region_131.jpg and saved.
# Text extracted from region_132.jpg and saved.
# Text extracted from region_133.jpg and saved.
# Text extracted from region_134.jpg and saved.
# Text extracted from region_135.jpg and saved.
# Text extracted from region_136.jpg and saved.
# Text extracted from region_137.jpg and saved.
# Text extracted from region_138.jpg and saved.
# Text extracted from region_139.jpg and saved.
# Text extracted from region_14.jpg and saved.
# Text extracted from region_140.jpg and saved.
# Text extracted from region_141.jpg and saved.
# Text extracted from region_142.jpg and saved.
# Text extracted from region_143.jpg and saved.
# Text extracted from region_144.jpg and saved.
# Text extracted from region_145.jpg and saved.
# Text extracted from region_146.jpg and saved.
# Text extracted from region_147.jpg and saved.
# Text extracted from region_149.jpg and saved.
# Text extracted from region_15.jpg and saved.
# Text extracted from region_150.jpg and saved.
# Text extracted from region_151.jpg and saved.
# Text extracted from region_152.jpg and saved.
# Text extracted from region_153.jpg and saved.
# Text extracted from region_154.jpg and saved.
# Text extracted from region_155.jpg and saved.
# Text extracted from region_156.jpg and saved.
# Text extracted from region_158.jpg and saved.
# Text extracted from region_159.jpg and saved.
# Text extracted from region_16.jpg and saved.
# Text extracted from region_160.jpg and saved.
# Text extracted from region_162.jpg and saved.
# Text extracted from region_163.jpg and saved.
# Text extracted from region_164.jpg and saved.
# Text extracted from region_165.jpg and saved.
# Text extracted from region_166.jpg and saved.
# Text extracted from region_167.jpg and saved.
# Text extracted from region_168.jpg and saved.
# Text extracted from region_169.jpg and saved.
# Text extracted from region_17.jpg and saved.
# Text extracted from region_170.jpg and saved.
# Text extracted from region_171.jpg and saved.
# Text extracted from region_172.jpg and saved.
# Text extracted from region_173.jpg and saved.
# Text extracted from region_174.jpg and saved.
# Text extracted from region_175.jpg and saved.
# Text extracted from region_176.jpg and saved.
# Text extracted from region_177.jpg and saved.
# Text extracted from region_178.jpg and saved.
# Text extracted from region_179.jpg and saved.
# Text extracted from region_18.jpg and saved.
# Text extracted from region_180.jpg and saved.
# Text extracted from region_181.jpg and saved.
# Text extracted from region_182.jpg and saved.
# Text extracted from region_183.jpg and saved.
# Text extracted from region_184.jpg and saved.
# Text extracted from region_186.jpg and saved.
# Text extracted from region_187.jpg and saved.
# Text extracted from region_188.jpg and saved.
# Text extracted from region_189.jpg and saved.
# Text extracted from region_19.jpg and saved.
# Text extracted from region_190.jpg and saved.
# Text extracted from region_191.jpg and saved.
# Text extracted from region_192.jpg and saved.
# Text extracted from region_193.jpg and saved.
# Text extracted from region_195.jpg and saved.
# Text extracted from region_196.jpg and saved.
# Text extracted from region_197.jpg and saved.
# Text extracted from region_199.jpg and saved.
# Text extracted from region_2.jpg and saved.
# Text extracted from region_20.jpg and saved.
# Text extracted from region_200.jpg and saved.
# Text extracted from region_201.jpg and saved.
# Text extracted from region_203.jpg and saved.
# Text extracted from region_204.jpg and saved.
# Text extracted from region_205.jpg and saved.
# Text extracted from region_206.jpg and saved.
# Text extracted from region_207.jpg and saved.
# Text extracted from region_21.jpg and saved.
# Text extracted from region_210.jpg and saved.
# Text extracted from region_211.jpg and saved.
# Text extracted from region_212.jpg and saved.
# Text extracted from region_213.jpg and saved.
# Text extracted from region_215.jpg and saved.
# Text extracted from region_216.jpg and saved.
# Text extracted from region_217.jpg and saved.
# Text extracted from region_218.jpg and saved.
# Text extracted from region_22.jpg and saved.
# Text extracted from region_220.jpg and saved.
# Text extracted from region_221.jpg and saved.
# Text extracted from region_224.jpg and saved.
# Text extracted from region_225.jpg and saved.
# Text extracted from region_226.jpg and saved.
# Text extracted from region_227.jpg and saved.
# Text extracted from region_229.jpg and saved.
# Text extracted from region_23.jpg and saved.
# Text extracted from region_232.jpg and saved.
# Text extracted from region_233.jpg and saved.
# Text extracted from region_234.jpg and saved.
# Text extracted from region_237.jpg and saved.
# Text extracted from region_238.jpg and saved.
# Text extracted from region_239.jpg and saved.
# Text extracted from region_24.jpg and saved.
# Text extracted from region_245.jpg and saved.
# Text extracted from region_247.jpg and saved.
# Text extracted from region_248.jpg and saved.
# Text extracted from region_25.jpg and saved.
# Text extracted from region_252.jpg and saved.
# Text extracted from region_253.jpg and saved.
# Text extracted from region_255.jpg and saved.
# Text extracted from region_257.jpg and saved.
# Text extracted from region_258.jpg and saved.
# Text extracted from region_259.jpg and saved.
# Text extracted from region_26.jpg and saved.
# Text extracted from region_260.jpg and saved.
# Text extracted from region_261.jpg and saved.
# Text extracted from region_262.jpg and saved.
# Text extracted from region_263.jpg and saved.
# Text extracted from region_264.jpg and saved.
# Text extracted from region_267.jpg and saved.
# Text extracted from region_268.jpg and saved.
# Text extracted from region_269.jpg and saved.
# Text extracted from region_27.jpg and saved.
# Text extracted from region_272.jpg and saved.
# Text extracted from region_273.jpg and saved.
# Text extracted from region_277.jpg and saved.
# Text extracted from region_279.jpg and saved.
# Text extracted from region_28.jpg and saved.
# Text extracted from region_280.jpg and saved.
# Text extracted from region_288.jpg and saved.
# Text extracted from region_29.jpg and saved.
# Text extracted from region_293.jpg and saved.
# Text extracted from region_3.jpg and saved.
# Text extracted from region_30.jpg and saved.
# Text extracted from region_31.jpg and saved.
# Text extracted from region_318.jpg and saved.
# Text extracted from region_32.jpg and saved.
# Text extracted from region_321.jpg and saved.
# Text extracted from region_33.jpg and saved.
# Text extracted from region_330.jpg and saved.
# Text extracted from region_34.jpg and saved.
# Text extracted from region_35.jpg and saved.
# Text extracted from region_351.jpg and saved.
# Text extracted from region_359.jpg and saved.
# Text extracted from region_36.jpg and saved.
# Text extracted from region_366.jpg and saved.
# Text extracted from region_37.jpg and saved.
# Text extracted from region_373.jpg and saved.
# Text extracted from region_38.jpg and saved.
# Text extracted from region_39.jpg and saved.
# Text extracted from region_4.jpg and saved.
# Text extracted from region_40.jpg and saved.
# Text extracted from region_41.jpg and saved.
# Text extracted from region_42.jpg and saved.
# Text extracted from region_43.jpg and saved.
# Text extracted from region_44.jpg and saved.
# Text extracted from region_45.jpg and saved.
# Text extracted from region_46.jpg and saved.
# Text extracted from region_47.jpg and saved.
# Text extracted from region_48.jpg and saved.
# Text extracted from region_49.jpg and saved.
# Text extracted from region_5.jpg and saved.
# Text extracted from region_50.jpg and saved.
# Text extracted from region_51.jpg and saved.
# Text extracted from region_52.jpg and saved.
# Text extracted from region_53.jpg and saved.
# Text extracted from region_54.jpg and saved.
# Text extracted from region_55.jpg and saved.
# Text extracted from region_56.jpg and saved.
# Text extracted from region_57.jpg and saved.
# Text extracted from region_58.jpg and saved.
# Text extracted from region_59.jpg and saved.
# Text extracted from region_6.jpg and saved.
# Text extracted from region_60.jpg and saved.
# Text extracted from region_61.jpg and saved.
# Text extracted from region_62.jpg and saved.
# Text extracted from region_63.jpg and saved.
# Text extracted from region_64.jpg and saved.
# Text extracted from region_65.jpg and saved.
# Text extracted from region_66.jpg and saved.
# Text extracted from region_67.jpg and saved.
# Text extracted from region_68.jpg and saved.
# Text extracted from region_69.jpg and saved.
# Text extracted from region_7.jpg and saved.
# Text extracted from region_70.jpg and saved.
# Text extracted from region_71.jpg and saved.
# Text extracted from region_72.jpg and saved.
# Text extracted from region_73.jpg and saved.
# Text extracted from region_74.jpg and saved.
# Text extracted from region_75.jpg and saved.
# Text extracted from region_76.jpg and saved.
# Text extracted from region_77.jpg and saved.
# Text extracted from region_78.jpg and saved.
# Text extracted from region_79.jpg and saved.
# Text extracted from region_8.jpg and saved.
# Text extracted from region_80.jpg and saved.
# Text extracted from region_81.jpg and saved.
# Text extracted from region_82.jpg and saved.
# Text extracted from region_83.jpg and saved.
# Text extracted from region_84.jpg and saved.
# Text extracted from region_85.jpg and saved.
# Text extracted from region_86.jpg and saved.
# Text extracted from region_87.jpg and saved.
# Text extracted from region_88.jpg and saved.
# Text extracted from region_89.jpg and saved.
# Text extracted from region_9.jpg and saved.
# Text extracted from region_90.jpg and saved.
# Text extracted from region_91.jpg and saved.
# Text extracted from region_92.jpg and saved.
# Text extracted from region_93.jpg and saved.
# Text extracted from region_94.jpg and saved.
# Text extracted from region_95.jpg and saved.
# Text extracted from region_96.jpg and saved.
# Text extracted from region_97.jpg and saved.
# Text extracted from region_98.jpg and saved.
# Text extracted from region_99.jpg and saved.
# Text extracted from thyrocare_0_1001.jpg and saved.
# Text extracted from thyrocare_0_1174.jpg and saved.
# Text extracted from thyrocare_0_122.jpg and saved.
# Text extracted from thyrocare_0_123.jpg and saved.
# Text extracted from thyrocare_0_1248.jpg and saved.
# Text extracted from thyrocare_0_1374.jpg and saved.
# Text extracted from thyrocare_0_1861.jpg and saved.
# Text extracted from thyrocare_0_1915.jpg and saved.
# Text extracted from thyrocare_0_2177.jpg and saved.
# Text extracted from thyrocare_0_2300.jpg and saved.
# Text extracted from thyrocare_0_2505.jpg and saved.
# Text extracted from thyrocare_0_2649.jpg and saved.
# Text extracted from thyrocare_0_2691.jpg and saved.
# Text extracted from thyrocare_0_2737.jpg and saved.
# Text extracted from thyrocare_0_2838.jpg and saved.
# Text extracted from thyrocare_0_2841.jpg and saved.
# Text extracted from thyrocare_0_2866.jpg and saved.
# Text extracted from thyrocare_0_2885.jpg and saved.
# Text extracted from thyrocare_0_2987.jpg and saved.
# Text extracted from thyrocare_0_3333.jpg and saved.
# Text extracted from thyrocare_0_3414.jpg and saved.
# Text extracted from thyrocare_0_3439.jpg and saved.
# Text extracted from thyrocare_0_3558.jpg and saved.
# Text extracted from thyrocare_0_36.jpg and saved.
# Text extracted from thyrocare_0_3753.jpg and saved.
# Text extracted from thyrocare_0_3804.jpg and saved.
# Text extracted from thyrocare_0_3813.jpg and saved.
# Text extracted from thyrocare_0_4046.jpg and saved.
# Text extracted from thyrocare_0_421.jpg and saved.
# Text extracted from thyrocare_0_4385.jpg and saved.
# Text extracted from thyrocare_0_4468.jpg and saved.
# Text extracted from thyrocare_0_447.jpg and saved.
# Text extracted from thyrocare_0_4498.jpg and saved.
# Text extracted from thyrocare_0_4523.jpg and saved.
# Text extracted from thyrocare_0_4557.jpg and saved.
# Text extracted from thyrocare_0_4618.jpg and saved.
# Text extracted from thyrocare_0_4670.jpg and saved.
# Text extracted from thyrocare_0_4683.jpg and saved.
# Text extracted from thyrocare_0_4748.jpg and saved.
# Text extracted from thyrocare_0_4790.jpg and saved.
# Text extracted from thyrocare_0_4979.jpg and saved.
# Text extracted from thyrocare_0_5074.jpg and saved.
# Text extracted from thyrocare_0_511.jpg and saved.
# Text extracted from thyrocare_0_517.jpg and saved.
# Text extracted from thyrocare_0_532.jpg and saved.
# Text extracted from thyrocare_0_5338.jpg and saved.
# Text extracted from thyrocare_0_5357.jpg and saved.
# Text extracted from thyrocare_0_5503.jpg and saved.
# Text extracted from thyrocare_0_5608.jpg and saved.
# Text extracted from thyrocare_0_5640.jpg and saved.
# Text extracted from thyrocare_0_5816.jpg and saved.
# Text extracted from thyrocare_0_5858.jpg and saved.
# Text extracted from thyrocare_0_5879.jpg and saved.
# Text extracted from thyrocare_0_5896.jpg and saved.
# Text extracted from thyrocare_0_5928.jpg and saved.
# Text extracted from thyrocare_0_6185.jpg and saved.
# Text extracted from thyrocare_0_6214.jpg and saved.
# Text extracted from thyrocare_0_6222.jpg and saved.
# Text extracted from thyrocare_0_640.jpg and saved.
# Text extracted from thyrocare_0_657.jpg and saved.
# Text extracted from thyrocare_0_6698.jpg and saved.
# Text extracted from thyrocare_0_6716.jpg and saved.
# Text extracted from thyrocare_0_6723.jpg and saved.
# Text extracted from thyrocare_0_6743.jpg and saved.
# Text extracted from thyrocare_0_6884.jpg and saved.
# Text extracted from thyrocare_0_7075.jpg and saved.
# Text extracted from thyrocare_0_7082.jpg and saved.
# Text extracted from thyrocare_0_7083.jpg and saved.
# Text extracted from thyrocare_0_7109.jpg and saved.
# Text extracted from thyrocare_0_7219.jpg and saved.
# Text extracted from thyrocare_0_757.jpg and saved.
# Text extracted from thyrocare_0_7571.jpg and saved.
# Text extracted from thyrocare_0_7601.jpg and saved.
# Text extracted from thyrocare_0_7635.jpg and saved.
# Text extracted from thyrocare_0_7758.jpg and saved.
# Text extracted from thyrocare_0_7791.jpg and saved.
# Text extracted from thyrocare_0_7805.jpg and saved.
# Text extracted from thyrocare_0_8214.jpg and saved.
# Text extracted from thyrocare_0_8231.jpg and saved.
# Text extracted from thyrocare_0_8251.jpg and saved.
# Text extracted from thyrocare_0_8265.jpg and saved.
# Text extracted from thyrocare_0_8302.jpg and saved.
# Text extracted from thyrocare_0_8310.jpg and saved.
# Text extracted from thyrocare_0_838.jpg and saved.
# Text extracted from thyrocare_0_8394.jpg and saved.
# Text extracted from thyrocare_0_8491.jpg and saved.
# Text extracted from thyrocare_0_8748.jpg and saved.
# Text extracted from thyrocare_0_8749.jpg and saved.
# Text extracted from thyrocare_0_9047.jpg and saved.
# Text extracted from thyrocare_0_9076.jpg and saved.
# Text extracted from thyrocare_0_9108.jpg and saved.
# Text extracted from thyrocare_0_912.jpg and saved.
# Text extracted from thyrocare_0_9207.jpg and saved.
# Text extracted from thyrocare_0_9445.jpg and saved.
# Text extracted from thyrocare_0_9447.jpg and saved.
# Text extracted from thyrocare_0_9575.jpg and saved.
# Text extracted from thyrocare_0_9691.jpg and saved.
# Text extracted from thyrocare_0_9833.jpg and saved.
# Text extraction complete! CSV file saved.
